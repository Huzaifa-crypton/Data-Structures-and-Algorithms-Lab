# %%
class Node :
    key = None
    left = None
    right = None
    p = None
    def __init__(self,key):
        self.key = key 
    
class BST:
    def __init__(self):
        self.root = None
    def insert(self,z):
        n = Node(z)
        y = 0
        if (self.root == None):
            self.root = n
        else:
            y = self.root
            while y != None :
                if (z > y.key):
                    y = y.right
                else:
                    y = y.left
                    
            y = n  
#     def insert(T , z):
#         y = None
#         x = T.root
#         while x!= None:
#             y = x
#             if z.key < x.key:
#                 x = x.left
#             else:
#                 x = x.right
#         z.p = y
#         if (z == None):
#             T.root = z
#         elif z.key < y.key:
#             y.left = z
#         else:
#             y.right = z
def intraversal(T):
    if T != None:
        intraversal(T.left)
        print (T.key)
        intraversal(T.right)
def pretraversal(T):
    if T != None:
        print (T.key)
        pretraversal(T.left)
        pretraversal(T.right) 
def posttraversal(T):
    if T != None:
        posttraversal(T.left)
        posttraversal(T.right) 
        print (T.key)

#     def treeMin(x):
#         while x.left != None:
#             x = x.left
#         return x
#     def treeMax(x):
#         while x.right != None:
#             x = x.right
#         return x
#     def treeSuccessor(x):
#         if x.right != None :
#             return treeMin(x.right)
#         y = x.p
#         while y!=None and x==y.right
#             x = y
#             y = y.p
#         return y
#     def treePredecessor(x):
#         if x.left != None :
#             return treeMax(x.left)
#         y = x.p
#         while y!=None and x==y.left
#             x = y
#             y = y.p
#         return y
#     def treeSearch(root , x):
#         if (root.key == x):
#             return ("Found")
#         else:
#             if (root.key > x):
#                 root = root.left
#                 treeSearch(root , x)

#             elif (root.key < x):
#                 root = root.right
#                 treeSearch(root , x)
#     def nodeChilds(x):
#         if (x.left!=None):
#             print(x.left)
#             nodeChilds(x.left)
#         if (x.right !=None):
#             print(x.right)
#             nodeChild(x.right)
#     def Tranplant(T , u ,v):
#         if u.p == None :
#             T.root = v
#         elif u == u.p.left :
#             u.p.left = v
#         else 
#             u.p.right = v
#         if v != None :
#             v.p = u.p
#     def treeDelete(T , z):
#         if z.left ==None:
#             Transplant(T,z,z.right)
#         elif z.right ==None:
#             Transplant(T,z,z.left)
#         else:
#             y = treeMin(z.right)
#             if y.p != z:
#                 Transplant(T ,y,y.right)
#                 y.right = z.right
#                 y.right.p = y
#             Tranplant(T , z,y)
#             y.left = z.left

#             y.left.p = y
    
# T = RootNode()
# insert(t , Node(15))
T = BST()
T.insert(20)
intraversal(T.root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-48351b96d6c0> in <module>
#     127 T = BST()
#     128 T.insert(20)
# --> 129 intraversal(T)
#
# <ipython-input-7-48351b96d6c0> in intraversal(T)
#      42 def intraversal(T):
#      43     if T != None:
# ---> 44         intraversal(T.left)
#      45         print (T.key)
#      46         intraversal(T.right)
#
# AttributeError: 'BST' object has no attribute 'left'
