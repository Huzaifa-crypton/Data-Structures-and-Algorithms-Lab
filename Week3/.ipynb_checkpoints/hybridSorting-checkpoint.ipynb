# %%
def sortArray(A , B):
    i = 0
#     Selection sort
    for b in range(len(B)):
        for a in range(len(A)):
            if (A[a] == B[b]):
                y = A[i]
                A[i] = A[a]
                A[a] = y
                i+=1
    print(A)
#     Insertion Sort
    for j in range(i+1 , len(A)):
        num = A[j]
        for k in range(j-1 , i-1 , -1):
            if (A[j] < A[k]):
                
                A[k+1] = A[k]
#                 print("j"+str(j))
#                 print("k"+str(k))
#                 print(A)
#                 input("CHECK")
            else:
                A[k+1] = num
#                 print("j"+str(j))
#                 print("k"+str(k))
#                 print(A)
#                 input("INSERT")
    
#     for a in range (i , len(A)-1):
#         small = A[a]
#         idx = a
#         for b in range(a+1 , len(A)):
#             if (A[b] < small):
#                 small = A[b]
#                 idx = b
#         y = A[a]
#         A[a] = small
#         A[idx] = y
            
A = [5, 8, 9, 3, 5, 7, 1, 3, 4,9, 3, 5, 1, 8, 4]
B = [3, 5, 7, 2]                
sortArray(A,B)
print(A)
# Out:
# [3, 3, 3, 5, 5, 5, 7, 8, 4, 9, 9, 1, 1, 8, 4]
# j8
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 9, 9, 1, 1, 8, 4]
# CHECK
# j9
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 9, 9, 1, 1, 8, 4]
# INSERT
# j9
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 9, 1, 1, 8, 4]
# INSERT
# j10
# k9
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 9, 1, 1, 8, 4]
# INSERT
# j10
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 9, 1, 1, 8, 4]
# INSERT
# j10
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 9, 1, 1, 8, 4]
# INSERT
# j11
# k10
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 9, 9, 1, 8, 4]
# CHECK
# j11
# k9
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 9, 1, 9, 1, 8, 4]
# INSERT
# j11
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 9, 1, 1, 9, 1, 8, 4]
# INSERT
# j11
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 9, 1, 8, 4]
# INSERT
# j12
# k11
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 9, 9, 8, 4]
# CHECK
# j12
# k10
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 9, 8, 4]
# INSERT
# j12
# k9
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 9, 8, 4]
# INSERT
# j12
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 9, 8, 4]
# INSERT
# j12
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 9, 8, 4]
# INSERT
# j13
# k12
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 9, 9, 4]
# CHECK
# j13
# k11
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 1, 8, 9, 4]
# INSERT
# j13
# k10
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 1, 8, 8, 9, 4]
# INSERT
# j13
# k9
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 1, 8, 8, 8, 9, 4]
# INSERT
# j13
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 1, 8, 8, 8, 8, 9, 4]
# INSERT
# j13
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 8, 8, 8, 9, 4]
# INSERT
# j14
# k13
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 8, 8, 8, 9, 9]
# CHECK
# j14
# k12
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 8, 8, 8, 4, 9]
# INSERT
# j14
# k11
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 8, 8, 4, 4, 9]
# INSERT
# j14
# k10
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 8, 4, 4, 4, 9]
# INSERT
# j14
# k9
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 8, 4, 4, 4, 4, 9]
# INSERT
# j14
# k8
# [3, 3, 3, 5, 5, 5, 7, 8, 8, 4, 4, 4, 4, 4, 9]
# INSERT
# j14
# k7
# [3, 3, 3, 5, 5, 5, 7, 8, 4, 4, 4, 4, 4, 4, 9]
# INSERT
# [3, 3, 3, 5, 5, 5, 7, 8, 4, 4, 4, 4, 4, 4, 9]
